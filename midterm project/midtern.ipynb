# %%
#常數函數-輸出為常數 0
from qiskit import QuantumRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
qc = QuantumCircuit(qrx,qry)
qc.draw()

# %%
from qiskit import QuantumRegister,ClassicalRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
cr = ClassicalRegister(1,'c')
qc = QuantumCircuit(qrx,qry,cr)
qc.h(qrx)
qc.x(qry)
qc.h(qry)
qc.barrier()
qc.barrier()
qc.h(qrx)
qc.h(qry)
qc.measure(qrx,cr)
qc.draw()

# %%
from qiskit import QuantumCircuit, IBMQ, execute
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram
IBMQ.save_account('')
IBMQ.load_account()
provider=IBMQ.get_provider('ibm-q')
qcomp=provider.get_backend('ibmq_manila')
job=execute(qc, backend=qcomp, shots=1000)
job_monitor(job)
result = job.result()
counts = result.get_counts(qc)
print("Total counts for qubit states are :",counts)
plot_histogram(counts)
# Out:
# configrc.store_credentials:WARNING:2022-04-22 16:30:17,961: Credentials already present. Set overwrite=True to overwrite.
# ibmqfactory.load_account:WARNING:2022-04-22 16:30:18,292: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run
# Total counts for qubit states are : {'0': 986, '1': 14}

# %%
#常數函數-輸出為常數 1
from qiskit import QuantumRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
qc = QuantumCircuit(qrx,qry)
qc.x(qry)
qc.draw()

# %%
from qiskit import QuantumRegister,ClassicalRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
cr = ClassicalRegister(1,'c')
qc = QuantumCircuit(qrx,qry,cr)
qc.h(qrx)
qc.x(qry)
qc.h(qry)
qc.barrier()
qc.x(qry)
qc.barrier()
qc.h(qrx)
qc.h(qry)
qc.measure(qrx,cr)
qc.draw()

# %%
from qiskit import QuantumCircuit, IBMQ, execute
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram
IBMQ.load_account()
provider=IBMQ.get_provider('ibm-q')
qcomp=provider.get_backend('ibmq_manila')
job=execute(qc, backend=qcomp, shots=1000)
job_monitor(job)
result = job.result()
counts = result.get_counts(qc)
print("Total counts for qubit states are :",counts)
plot_histogram(counts)
# Out:
# ibmqfactory.load_account:WARNING:2022-04-22 17:07:49,063: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run
# Total counts for qubit states are : {'0': 986, '1': 14}

# %%
#平衡函數-輸出與輸入相等
from qiskit import QuantumRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
qc = QuantumCircuit(qrx,qry)
qc.cx(qrx, qry)
qc.draw()

# %%
from qiskit import QuantumRegister,ClassicalRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
cr = ClassicalRegister(1,'c')
qc = QuantumCircuit(qrx,qry,cr)
qc.h(qrx)
qc.x(qry)
qc.h(qry)
qc.barrier()
qc.cx(qrx, qry)
qc.barrier()
qc.h(qrx)
qc.h(qry)
qc.measure(qrx,cr)
qc.draw()

# %%
from qiskit import QuantumCircuit, IBMQ, execute
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram
IBMQ.load_account()
provider=IBMQ.get_provider('ibm-q')
qcomp=provider.get_backend('ibmq_manila')
job=execute(qc, backend=qcomp, shots=1000)
job_monitor(job)
result = job.result()
counts = result.get_counts(qc)
print("Total counts for qubit states are :",counts)
plot_histogram(counts)
# Out:
# ibmqfactory.load_account:WARNING:2022-04-22 17:21:18,378: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run
# Total counts for qubit states are : {'0': 27, '1': 973}

# %%
#平衡函數-輸出與輸入相反
from qiskit import QuantumRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
qc = QuantumCircuit(qrx,qry)
qc.x(qrx)
qc.cx(qrx, qry)
qc.draw()

# %%
from qiskit import QuantumRegister,ClassicalRegister,QuantumCircuit
qrx = QuantumRegister(1,'x')
qry = QuantumRegister(1,'y')
cr = ClassicalRegister(1,'c')
qc = QuantumCircuit(qrx,qry,cr)
qc.h(qrx)
qc.x(qry)
qc.h(qry)
qc.barrier()
qc.x(qrx)
qc.cx(qrx, qry)
qc.barrier()
qc.h(qrx)
qc.h(qry)
qc.measure(qrx,cr)
qc.draw()

# %%
from qiskit import QuantumCircuit, IBMQ, execute
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram
IBMQ.load_account()
provider=IBMQ.get_provider('ibm-q')
qcomp=provider.get_backend('ibmq_manila')
job=execute(qc, backend=qcomp, shots=1000)
job_monitor(job)
result = job.result()
counts = result.get_counts(qc)
print("Total counts for qubit states are :",counts)
plot_histogram(counts)
# Out:
# ibmqfactory.load_account:WARNING:2022-04-22 17:32:52,980: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run
# Total counts for qubit states are : {'0': 44, '1': 956}
